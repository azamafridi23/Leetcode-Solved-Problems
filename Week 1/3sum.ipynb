# %% [markdown]
# ![image.png](attachment:image.png)
#
# Link: https://leetcode.com/problems/3sum/solutions/3186495/best-c-3-solution-two-pointers-sorting-hash-table-brute-force-optimize/
#
# Video Explanation: https://www.youtube.com/watch?v=jzZsG8n2R9A

# %% [markdown]
# Solution: https://leetcode.com/problems/3sum/solutions/4614728/11-2-approach-2-o-n-2-python-c-step-by-step-explanation/

# %%
# Python Solution
class Solution:
    def threeSum(self, nums: list[int]) -> list[list[int]]:
        ans = []
        # Sort the array to simplify the process of finding triplets.
        nums.sort()

        for i, a in enumerate(nums):
            # Skip positive integers since the sum of three positive integers can't be zero.
            if a > 0:
                break

            # Skip duplicate elements to avoid duplicate triplets.
            if i > 0 and a == nums[i - 1]:
                continue

            # Use two pointers to find a pair with a sum of -a.
            l, r = i + 1, len(nums) - 1
            while l < r:
                threeSum = a + nums[l] + nums[r]
                if threeSum > 0:
                    r -= 1
                elif threeSum < 0:
                    l += 1
                else:
                    ans.append([a, nums[l], nums[r]])
                    l += 1
                    r -= 1
                    # Skip duplicate elements to avoid duplicate triplets.
                    while nums[l] == nums[l - 1] and l < r:
                        l += 1
                        
        return ans
